# %% [markdown]
# <a href="https://colab.research.google.com/github/KoreTane/KoreTane/blob/main/Forecasting_marketing_investments_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import warnings

# %%
dfm = pd.read_excel('MatriculaCEP.xlsx')
dfc = pd.read_excel('fluxo_caixa_cbs.xlsx')

# %%
# Extrair a coluna a partir do 2 delimitador '#'
dfc['Matricula'] = dfc['Descrição'].str.split('#', expand=True)[2]
# Remover os caracteres '#\d+' da coluna 'Descrição'
dfc['Aluno'] = dfc['Descrição'].str.replace(r'#\d+', '', regex=True)
dfc = dfc[['Matricula', 'Data', 'Aluno', 'Valor', 'Tipo']]
warnings.filterwarnings('ignore')

# %%
#countclients = dfc['Aluno'].value_counts()

# %%
dfc
# Out:
#      Matricula       Data     Aluno   Valor      Tipo
# 0        23017 2023-01-11  #CLIENTE  244.02    Débito
# 1        23018 2023-01-12  #CLIENTE  199.00  Dinheiro
# 2        23002 2023-01-13  #CLIENTE  237.12   Crédito
# 3        23003 2023-01-13  #CLIENTE  237.12   Crédito
# 4        23007 2023-01-14  #CLIENTE  250.00  Dinheiro
# ...        ...        ...       ...     ...       ...
# 1306     24024 2024-04-15  #CLIENTE  230.00  Dinheiro
# 1307     24024 2024-04-17  #CLIENTE  164.07   Crédito
# 1308     24023 2024-04-23  #CLIENTE  316.89   Crédito
# 1309     24023 2024-04-23  #CLIENTE  358.34   Crédito
# 1310     24025 2024-04-24  #CLIENTE   82.03   Crédito
#
# [1311 rows x 5 columns]

# %%
dfc['Tipo'].unique()
# Out:
# array(['Débito', 'Dinheiro', 'Crédito', 'Aporte pessoal', 'Boleto',
#        'Investimento', 'Espetáculo'], dtype=object)

# %%
dfc[dfc['Tipo'] == 'Dinheiro']
# Out:
#      Matricula       Data     Aluno   Valor      Tipo
# 1        23018 2023-01-12  #CLIENTE  199.00  Dinheiro
# 4        23007 2023-01-14  #CLIENTE  250.00  Dinheiro
# 5        23020 2023-01-16  #CLIENTE  250.00  Dinheiro
# 6        23021 2023-01-16  #CLIENTE  124.95  Dinheiro
# 7        23022 2023-01-17  #CLIENTE  250.00  Dinheiro
# ...        ...        ...       ...     ...       ...
# 1301     23058 2024-04-10  #CLIENTE  410.00  Dinheiro
# 1302     24029 2024-04-10  #CLIENTE  100.00  Dinheiro
# 1304     23021 2024-04-15  #CLIENTE  185.00  Dinheiro
# 1305     23040 2024-04-15  #CLIENTE  370.00  Dinheiro
# 1306     24024 2024-04-15  #CLIENTE  230.00  Dinheiro
#
# [305 rows x 5 columns]
